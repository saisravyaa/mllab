# %%
#use iris data set that consists of 5 columns(sepal length, sepal width, petal length, petal width, species)  and perform the pca on the dataset. examine the first 2 principal components of x. create a scatterplot with each of 150 rows of x projected onto the first two principal components. in other words, the horizantal axis should be first principal component, the vertical axis should be the second principal component without using scikit learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\sravy\\Desktop\\ml lab\\iris(For PCA Program) (1).csv')
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        1
# 1           4.9          3.0           1.4          0.2        1
# 2           4.7          3.2           1.3          0.2        1
# 3           4.6          3.1           1.5          0.2        1
# 4           5.0          3.6           1.4          0.2        1

# %%
# Extract the feature columns (excluding the 'species' column)
x = data.drop('species',axis = 1)
x.head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
#standardize the data
x_stand = (x - np.mean(x,axis=0))/np.std(x,axis=0)

# %%
#covariance matrix
cov = np.cov(x_stand,rowvar=False)

# %%
#calculate egien vectors and eigen values
eigenv,eigenv1 = np.linalg.eig(cov)

# %%
#sorting
sorted_index = np.argsort(eigenv)[::-1]
eigenv = eigenv[sorted_index]
eigenv1 = eigenv1[:,sorted_index]

# %%
#plotting
x_pca = np.dot(x_stand,eigenv1[:,:2])

# %%
# Scatterplot of the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(x_pca[:, 0], x_pca[:, 1], c=data['species'], cmap='viridis', edgecolor='k', s=50)
plt.title('Scatterplot of Iris Dataset - First 2 Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

# Display the plot
plt.show()
